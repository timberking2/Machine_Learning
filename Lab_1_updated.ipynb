# %% [markdown]
# <a href="https://colab.research.google.com/github/timberking2/Machine_Learning/blob/main/Lab_1_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ca_offenses_by_city.csv')
df
# Out:
#              City Population Violent crime  \
# 0        Adelanto     33,005           212
# 1    Agoura Hills     20,970            15
# 2         Alameda     78,613           148
# 3          Albany     19,723            34
# 4       Alhambra3     86,175           168
# ..            ...        ...           ...
# 455   Yountville3      3,030             7
# 456         Yreka      7,507            47
# 457     Yuba City     65,974           216
# 458       Yucaipa     53,498            94
# 459  Yucca Valley     21,672           151
#
#      Murder and nonnegligent manslaughter Rape (revised definition)  \
# 0                                       2                        14
# 1                                       0                         1
# 2                                       2                         7
# 3                                       1                         6
# 4                                       1                        13
# ..                                    ...                       ...
# 455                                     0                         0
# 456                                     1                         4
# 457                                     0                        28
# 458                                     2                         8
# 459                                     0                         8
#
#      Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 0                         NaN      48                148            808
# 1                         NaN       6                  8            310
# 2                         NaN      61                 78          1,819
# 3                         NaN      16                 11            605
# 4                         NaN      74                 80          1,929
# ..                        ...     ...                ...            ...
# 455                       NaN       0                  7             46
# 456                       NaN       4                 38            309
# 457                       NaN      66                122          1,792
# 458                       NaN      22                 62          1,309
# 459                       NaN      30                113            664
#
#     Burglary Larceny-theft Motor vehicle theft Arson
# 0        434           254                 120    24
# 1         82           217                  11     0
# 2        228         1,245                 346    18
# 3         95           447                  63     0
# 4        305         1,413                 211     6
# ..       ...           ...                 ...   ...
# 455        7            36                   3     0
# 456       85           188                  36     1
# 457      429         1,160                 203    14
# 458      263           838                 208    12
# 459      217           381                  66     8
#
# [460 rows x 13 columns]

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
list(df.columns)
# Out:
# ['City',
#  'Population',
#  'Violent crime',
#  'Murder and nonnegligent manslaughter',
#  'Rape (revised definition)',
#  'Rape (legacy definition)',
#  'Robbery',
#  'Aggravated assault',
#  'Property crime',
#  'Burglary',
#  'Larceny-theft',
#  'Motor vehicle theft',
#  'Arson']

# %%
df.head(5)
# Out:
#            City Population Violent crime  \
# 0      Adelanto     33,005           212
# 1  Agoura Hills     20,970            15
# 2       Alameda     78,613           148
# 3        Albany     19,723            34
# 4     Alhambra3     86,175           168
#
#    Murder and nonnegligent manslaughter Rape (revised definition)  \
# 0                                     2                        14
# 1                                     0                         1
# 2                                     2                         7
# 3                                     1                         6
# 4                                     1                        13
#
#    Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 0                       NaN      48                148            808
# 1                       NaN       6                  8            310
# 2                       NaN      61                 78          1,819
# 3                       NaN      16                 11            605
# 4                       NaN      74                 80          1,929
#
#   Burglary Larceny-theft Motor vehicle theft Arson
# 0      434           254                 120    24
# 1       82           217                  11     0
# 2      228         1,245                 346    18
# 3       95           447                  63     0
# 4      305         1,413                 211     6

# %%
df.tail(5)
# Out:
#              City Population Violent crime  \
# 455   Yountville3      3,030             7
# 456         Yreka      7,507            47
# 457     Yuba City     65,974           216
# 458       Yucaipa     53,498            94
# 459  Yucca Valley     21,672           151
#
#      Murder and nonnegligent manslaughter Rape (revised definition)  \
# 455                                     0                         0
# 456                                     1                         4
# 457                                     0                        28
# 458                                     2                         8
# 459                                     0                         8
#
#      Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 455                       NaN       0                  7             46
# 456                       NaN       4                 38            309
# 457                       NaN      66                122          1,792
# 458                       NaN      22                 62          1,309
# 459                       NaN      30                113            664
#
#     Burglary Larceny-theft Motor vehicle theft Arson
# 455        7            36                   3     0
# 456       85           188                  36     1
# 457      429         1,160                 203    14
# 458      263           838                 208    12
# 459      217           381                  66     8

# %%
df.describe(include="all")
# Out:
#             City Population Violent crime  \
# count        460        460           460
# unique       460        460           257
# top     Adelanto     33,005             1
# freq           1          1            12
# mean         NaN        NaN           NaN
# std          NaN        NaN           NaN
# min          NaN        NaN           NaN
# 25%          NaN        NaN           NaN
# 50%          NaN        NaN           NaN
# 75%          NaN        NaN           NaN
# max          NaN        NaN           NaN
#
#         Murder and nonnegligent manslaughter Rape (revised definition)  \
# count                             460.000000                       460
# unique                                   NaN                        74
# top                                      NaN                         0
# freq                                     NaN                        47
# mean                                3.165217                       NaN
# std                                14.971101                       NaN
# min                                 0.000000                       NaN
# 25%                                 0.000000                       NaN
# 50%                                 1.000000                       NaN
# 75%                                 2.000000                       NaN
# max                               282.000000                       NaN
#
#         Rape (legacy definition) Robbery Aggravated assault Property crime  \
# count                        0.0     460                460            460
# unique                       NaN     158                207            425
# top                          NaN       0                  1            150
# freq                         NaN      33                 14              3
# mean                         NaN     NaN                NaN            NaN
# std                          NaN     NaN                NaN            NaN
# min                          NaN     NaN                NaN            NaN
# 25%                          NaN     NaN                NaN            NaN
# 50%                          NaN     NaN                NaN            NaN
# 75%                          NaN     NaN                NaN            NaN
# max                          NaN     NaN                NaN            NaN
#
#        Burglary Larceny-theft Motor vehicle theft Arson
# count       460           460                 460   460
# unique      310           394                 271    56
# top          80            64                   3     0
# freq          6             4                   9   105
# mean        NaN           NaN                 NaN   NaN
# std         NaN           NaN                 NaN   NaN
# min         NaN           NaN                 NaN   NaN
# 25%         NaN           NaN                 NaN   NaN
# 50%         NaN           NaN                 NaN   NaN
# 75%         NaN           NaN                 NaN   NaN
# max         NaN           NaN                 NaN   NaN

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.  Ответ
# 2.  Ответ

# %%
# Первый ответ
df.mean()
# Out:
# <ipython-input-32-9a6813b6fbe8>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Murder and nonnegligent manslaughter    3.165217
# Rape (legacy definition)                     NaN
# dtype: float64

# %%
# Второй ответ
df.min()
# Out:
# City                                     Adelanto
# Population                              1,031,458
# Violent crime                                   0
# Murder and nonnegligent manslaughter            0
# Rape (revised definition)                       0
# Rape (legacy definition)                      NaN
# Robbery                                         0
# Aggravated assault                              0
# Property crime                              1,028
# Burglary                                        0
# Larceny-theft                               1,004
# Motor vehicle theft                             0
# Arson                                           0
# dtype: object

# %%
#Второй ответ
df.max()
# Out:
# City                                    Yucca Valley
# Population                                    99,706
# Violent crime                                     99
# Murder and nonnegligent manslaughter             282
# Rape (revised definition)                         98
# Rape (legacy definition)                         NaN
# Robbery                                           99
# Aggravated assault                                99
# Property crime                                   998
# Burglary                                          99
# Larceny-theft                                    996
# Motor vehicle theft                               99
# Arson                                             93
# dtype: object

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
for col in df.columns:
  if col == 'City':
    continue
  df[col] = df[col].astype(str).str.replace(',','')
for col in df.columns:
  if col == 'City':
    df[col].astype("category")
    continue
  df[col] = df[col].astype('Float64')

df.dtypes
# Out:
# City                                     object
# Population                              Float64
# Violent crime                           Float64
# Murder and nonnegligent manslaughter    Float64
# Rape (revised definition)               Float64
# Rape (legacy definition)                Float64
# Robbery                                 Float64
# Aggravated assault                      Float64
# Property crime                          Float64
# Burglary                                Float64
# Larceny-theft                           Float64
# Motor vehicle theft                     Float64
# Arson                                   Float64
# dtype: object

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# Ответ - количественные поля: population, arson, violent crime и т.д.
# Категориальные: City

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#колонка 1
df[df['Murder and nonnegligent manslaughter'] >= 66]
# Out:
#             City  Population  Violent crime  \
# 233  Los Angeles   3962726.0        25156.0
# 281      Oakland    419481.0         6051.0
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 233                                 282.0                     2209.0
# 281                                  85.0                      285.0
#
#      Rape (legacy definition)  Robbery  Aggravated assault  Property crime  \
# 233                       NaN   8952.0             13713.0         93503.0
# 281                       NaN   3290.0              2391.0         24568.0
#
#      Burglary  Larceny-theft  Motor vehicle theft   Arson
# 233   16160.0        61191.0              16152.0  1131.0
# 281    3333.0        14846.0               6389.0   179.0

# %%
#колонка 2
df[df['Population'] > 1234567]
# Out:
#             City  Population  Violent crime  \
# 233  Los Angeles   3962726.0        25156.0
# 351    San Diego   1400467.0         5582.0
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 233                                 282.0                     2209.0
# 351                                  37.0                      566.0
#
#      Rape (legacy definition)  Robbery  Aggravated assault  Property crime  \
# 233                       NaN   8952.0             13713.0         93503.0
# 351                       NaN   1378.0              3601.0         29158.0
#
#      Burglary  Larceny-theft  Motor vehicle theft   Arson
# 233   16160.0        61191.0              16152.0  1131.0
# 351    5129.0        18933.0               5096.0   174.0

# %%
#колонка 3
df[(df['Murder and nonnegligent manslaughter'] < 2)  & (df['Population'] > 111111)]
# Out:
#                  City  Population  Violent crime  \
# 36           Berkeley    120387.0          530.0
# 61           Carlsbad    113972.0          172.0
# 93        Costa Mesa3    113477.0          386.0
# 123         Elk Grove    166183.0          586.0
# 149        Fullerton3    140771.0          389.0
# 180  Huntington Beach    203233.0          420.0
# 343         Roseville    131039.0          239.0
# 370       Santa Clara    123562.0          156.0
# 389      Simi Valley3    127472.0          174.0
# 405         Sunnyvale    152443.0          158.0
# 410          Temecula    111673.0          114.0
# 412     Thousand Oaks    129976.0          136.0
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 36                                    1.0                       44.0
# 61                                    0.0                       33.0
# 93                                    1.0                       53.0
# 123                                   1.0                       33.0
# 149                                   0.0                       66.0
# 180                                   0.0                       52.0
# 343                                   0.0                       23.0
# 370                                   1.0                       20.0
# 389                                   1.0                       24.0
# 405                                   1.0                       29.0
# 410                                   1.0                        8.0
# 412                                   0.0                       26.0
#
#      Rape (legacy definition)  Robbery  Aggravated assault  Property crime  \
# 36                        NaN    330.0               155.0          5906.0
# 61                        NaN     38.0               101.0          2134.0
# 93                        NaN    122.0               210.0          4723.0
# 123                       NaN    105.0               447.0          3120.0
# 149                       NaN    110.0               213.0          3893.0
# 180                       NaN    117.0               251.0          4942.0
# 343                       NaN     84.0               132.0          3295.0
# 370                       NaN     71.0                64.0          3579.0
# 389                       NaN     45.0               104.0          1513.0
# 405                       NaN     61.0                67.0          2355.0
# 410                       NaN     47.0                58.0          2917.0
# 412                       NaN     23.0                87.0          1577.0
#
#      Burglary  Larceny-theft  Motor vehicle theft  Arson
# 36     1090.0         4099.0                717.0   22.0
# 61      366.0         1627.0                141.0    8.0
# 93      698.0         3558.0                467.0   18.0
# 123     589.0         2294.0                237.0    4.0
# 149     468.0         2958.0                467.0   15.0
# 180     723.0         3846.0                373.0   23.0
# 343     521.0         2469.0                305.0   10.0
# 370     583.0         2598.0                398.0   10.0
# 389     255.0         1146.0                112.0    6.0
# 405     545.0         1514.0                296.0    9.0
# 410     459.0         2116.0                342.0    3.0
# 412     234.0         1241.0                102.0    9.0

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
df['Violent crime'] = pd.qcut(df['Violent crime'], 4, labels=["Peacefuel","Somebody dies",'Lot guys are dies', 'Yooo blood bathhh'])

df
# Out:
#              City  Population      Violent crime  \
# 0        Adelanto     33005.0  Lot guys are dies
# 1    Agoura Hills     20970.0          Peacefuel
# 2         Alameda     78613.0  Lot guys are dies
# 3          Albany     19723.0      Somebody dies
# 4       Alhambra3     86175.0  Lot guys are dies
# ..            ...         ...                ...
# 455   Yountville3      3030.0          Peacefuel
# 456         Yreka      7507.0      Somebody dies
# 457     Yuba City     65974.0  Yooo blood bathhh
# 458       Yucaipa     53498.0  Lot guys are dies
# 459  Yucca Valley     21672.0  Lot guys are dies
#
#      Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 0                                     2.0                       14.0
# 1                                     0.0                        1.0
# 2                                     2.0                        7.0
# 3                                     1.0                        6.0
# 4                                     1.0                       13.0
# ..                                    ...                        ...
# 455                                   0.0                        0.0
# 456                                   1.0                        4.0
# 457                                   0.0                       28.0
# 458                                   2.0                        8.0
# 459                                   0.0                        8.0
#
#      Rape (legacy definition)  Robbery  Aggravated assault  Property crime  \
# 0                         NaN     48.0               148.0           808.0
# 1                         NaN      6.0                 8.0           310.0
# 2                         NaN     61.0                78.0          1819.0
# 3                         NaN     16.0                11.0           605.0
# 4                         NaN     74.0                80.0          1929.0
# ..                        ...      ...                 ...             ...
# 455                       NaN      0.0                 7.0            46.0
# 456                       NaN      4.0                38.0           309.0
# 457                       NaN     66.0               122.0          1792.0
# 458                       NaN     22.0                62.0          1309.0
# 459                       NaN     30.0               113.0           664.0
#
#      Burglary  Larceny-theft  Motor vehicle theft  Arson
# 0       434.0          254.0                120.0   24.0
# 1        82.0          217.0                 11.0    0.0
# 2       228.0         1245.0                346.0   18.0
# 3        95.0          447.0                 63.0    0.0
# 4       305.0         1413.0                211.0    6.0
# ..        ...            ...                  ...    ...
# 455       7.0           36.0                  3.0    0.0
# 456      85.0          188.0                 36.0    1.0
# 457     429.0         1160.0                203.0   14.0
# 458     263.0          838.0                208.0   12.0
# 459     217.0          381.0                 66.0    8.0
#
# [460 rows x 13 columns]

# %%
#Группировка
df.groupby('Violent crime').mean()
# Out:
# <ipython-input-40-84f937330b9a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Violent crime').mean()
#                       Population  Murder and nonnegligent manslaughter  \
# Violent crime
# Peacefuel            10393.12069                              0.172414
# Somebody dies        28719.87931                              0.543103
# Lot guys are dies   53757.513274                              1.371681
# Yooo blood bathhh  188832.269565                             10.591304
#
#                    Rape (revised definition)  Rape (legacy definition)  \
# Violent crime
# Peacefuel                           1.413793                      <NA>
# Somebody dies                            6.0                      <NA>
# Lot guys are dies                  12.150442                      <NA>
# Yooo blood bathhh                  73.391304                      <NA>
#
#                       Robbery  Aggravated assault  Property crime  \
# Violent crime
# Peacefuel                2.75            7.922414      180.853448
# Somebody dies       14.603448                33.5      605.034483
# Lot guys are dies   39.814159           84.725664     1313.911504
# Yooo blood bathhh  351.356522          555.834783     5589.069565
#
#                       Burglary  Larceny-theft  Motor vehicle theft      Arson
# Violent crime
# Peacefuel            41.517241     121.568966            17.767241   0.905172
# Somebody dies       116.577586     423.258621            65.198276    2.87069
# Lot guys are dies   242.690265     896.061947           175.159292   7.610619
# Yooo blood bathhh  1012.747826    3578.130435           998.191304  41.782609

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
