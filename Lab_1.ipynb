# %% [markdown]
# <a href="https://colab.research.google.com/github/timberking2/Machine_Learning/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("ca_offenses_by_city.csv")
#df.columns = df.columns.str.replace(' ', '_')
#df.columns = df.columns.str.replace('/', '_')
#df.columns = df.columns.str.replace('(', '')
#df.columns = df.columns.str.replace(')', '')
#df.columns = df.columns.str.replace('-', '_')
#df.columns = df.columns.str.replace(',', '')
#df.dropna ()

df
# Все замены были для /content/ca_offenses_by_county.csv, поменял цсвшник чтоб не мешали NaN'ы
# Out:
#              City Population Violent crime  \
# 0        Adelanto     33,005           212
# 1    Agoura Hills     20,970            15
# 2         Alameda     78,613           148
# 3          Albany     19,723            34
# 4       Alhambra3     86,175           168
# ..            ...        ...           ...
# 455   Yountville3      3,030             7
# 456         Yreka      7,507            47
# 457     Yuba City     65,974           216
# 458       Yucaipa     53,498            94
# 459  Yucca Valley     21,672           151
#
#      Murder and nonnegligent manslaughter Rape (revised definition)  \
# 0                                       2                        14
# 1                                       0                         1
# 2                                       2                         7
# 3                                       1                         6
# 4                                       1                        13
# ..                                    ...                       ...
# 455                                     0                         0
# 456                                     1                         4
# 457                                     0                        28
# 458                                     2                         8
# 459                                     0                         8
#
#      Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 0                         NaN      48                148            808
# 1                         NaN       6                  8            310
# 2                         NaN      61                 78          1,819
# 3                         NaN      16                 11            605
# 4                         NaN      74                 80          1,929
# ..                        ...     ...                ...            ...
# 455                       NaN       0                  7             46
# 456                       NaN       4                 38            309
# 457                       NaN      66                122          1,792
# 458                       NaN      22                 62          1,309
# 459                       NaN      30                113            664
#
#     Burglary Larceny-theft Motor vehicle theft Arson
# 0        434           254                 120    24
# 1         82           217                  11     0
# 2        228         1,245                 346    18
# 3         95           447                  63     0
# 4        305         1,413                 211     6
# ..       ...           ...                 ...   ...
# 455        7            36                   3     0
# 456       85           188                  36     1
# 457      429         1,160                 203    14
# 458      263           838                 208    12
# 459      217           381                  66     8
#
# [460 rows x 13 columns]

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
list(df.columns)
# Out:
# ['City',
#  'Population',
#  'Violent crime',
#  'Murder and nonnegligent manslaughter',
#  'Rape (revised definition)',
#  'Rape (legacy definition)',
#  'Robbery',
#  'Aggravated assault',
#  'Property crime',
#  'Burglary',
#  'Larceny-theft',
#  'Motor vehicle theft',
#  'Arson']

# %%
df.head(5)
# Out:
#            City Population Violent crime  \
# 0      Adelanto     33,005           212
# 1  Agoura Hills     20,970            15
# 2       Alameda     78,613           148
# 3        Albany     19,723            34
# 4     Alhambra3     86,175           168
#
#    Murder and nonnegligent manslaughter Rape (revised definition)  \
# 0                                     2                        14
# 1                                     0                         1
# 2                                     2                         7
# 3                                     1                         6
# 4                                     1                        13
#
#    Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 0                       NaN      48                148            808
# 1                       NaN       6                  8            310
# 2                       NaN      61                 78          1,819
# 3                       NaN      16                 11            605
# 4                       NaN      74                 80          1,929
#
#   Burglary Larceny-theft Motor vehicle theft Arson
# 0      434           254                 120    24
# 1       82           217                  11     0
# 2      228         1,245                 346    18
# 3       95           447                  63     0
# 4      305         1,413                 211     6

# %%
df.tail(5)
# Out:
#              City Population Violent crime  \
# 455   Yountville3      3,030             7
# 456         Yreka      7,507            47
# 457     Yuba City     65,974           216
# 458       Yucaipa     53,498            94
# 459  Yucca Valley     21,672           151
#
#      Murder and nonnegligent manslaughter Rape (revised definition)  \
# 455                                     0                         0
# 456                                     1                         4
# 457                                     0                        28
# 458                                     2                         8
# 459                                     0                         8
#
#      Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 455                       NaN       0                  7             46
# 456                       NaN       4                 38            309
# 457                       NaN      66                122          1,792
# 458                       NaN      22                 62          1,309
# 459                       NaN      30                113            664
#
#     Burglary Larceny-theft Motor vehicle theft Arson
# 455        7            36                   3     0
# 456       85           188                  36     1
# 457      429         1,160                 203    14
# 458      263           838                 208    12
# 459      217           381                  66     8

# %%
df.describe(include="all")
# Out:
#             City Population Violent crime  \
# count        460        460           460
# unique       460        460           257
# top     Adelanto     33,005             1
# freq           1          1            12
# mean         NaN        NaN           NaN
# std          NaN        NaN           NaN
# min          NaN        NaN           NaN
# 25%          NaN        NaN           NaN
# 50%          NaN        NaN           NaN
# 75%          NaN        NaN           NaN
# max          NaN        NaN           NaN
#
#         Murder and nonnegligent manslaughter Rape (revised definition)  \
# count                             460.000000                       460
# unique                                   NaN                        74
# top                                      NaN                         0
# freq                                     NaN                        47
# mean                                3.165217                       NaN
# std                                14.971101                       NaN
# min                                 0.000000                       NaN
# 25%                                 0.000000                       NaN
# 50%                                 1.000000                       NaN
# 75%                                 2.000000                       NaN
# max                               282.000000                       NaN
#
#         Rape (legacy definition) Robbery Aggravated assault Property crime  \
# count                        0.0     460                460            460
# unique                       NaN     158                207            425
# top                          NaN       0                  1            150
# freq                         NaN      33                 14              3
# mean                         NaN     NaN                NaN            NaN
# std                          NaN     NaN                NaN            NaN
# min                          NaN     NaN                NaN            NaN
# 25%                          NaN     NaN                NaN            NaN
# 50%                          NaN     NaN                NaN            NaN
# 75%                          NaN     NaN                NaN            NaN
# max                          NaN     NaN                NaN            NaN
#
#        Burglary Larceny-theft Motor vehicle theft Arson
# count       460           460                 460   460
# unique      310           394                 271    56
# top          80            64                   3     0
# freq          6             4                   9   105
# mean        NaN           NaN                 NaN   NaN
# std         NaN           NaN                 NaN   NaN
# min         NaN           NaN                 NaN   NaN
# 25%         NaN           NaN                 NaN   NaN
# 50%         NaN           NaN                 NaN   NaN
# 75%         NaN           NaN                 NaN   NaN
# max         NaN           NaN                 NaN   NaN

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.  Ответ
# 2.  Ответ

# %%
# Первый ответ
df.mean()
# Out:
# <ipython-input-114-9a6813b6fbe8>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Murder and nonnegligent manslaughter    3.165217
# Rape (legacy definition)                     NaN
# dtype: float64

# %%
# Второй ответ
df.min()
# Out:
# City                                     Adelanto
# Population                              1,031,458
# Violent crime                                   0
# Murder and nonnegligent manslaughter            0
# Rape (revised definition)                       0
# Rape (legacy definition)                      NaN
# Robbery                                         0
# Aggravated assault                              0
# Property crime                              1,028
# Burglary                                        0
# Larceny-theft                               1,004
# Motor vehicle theft                             0
# Arson                                           0
# dtype: object

# %%
#Второй ответ
df.max()
# Out:
# City                                    Yucca Valley
# Population                                    99,706
# Violent crime                                     99
# Murder and nonnegligent manslaughter             282
# Rape (revised definition)                         98
# Rape (legacy definition)                         NaN
# Robbery                                           99
# Aggravated assault                                99
# Property crime                                   998
# Burglary                                          99
# Larceny-theft                                    996
# Motor vehicle theft                               99
# Arson                                             93
# dtype: object

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
arrX =[]
arrY = []
arrZ = []

for i in df.columns:
  if df[i].dtype == 'int64':
    arrX.append(i)
  else:
    arrY.append(i)

# %%
def clean_currency(x):
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return(x)
# Out:
# <class 'float'>    460
# Name: Population, dtype: int64

# %%
for k in arrX:
    df[k] = df[k].astype('Int64')

for j in arrY:
    df[j] = df[j].astype('category')
df['Population'].apply(type).value_counts()
def clean_currency(x):
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return(x)
df['Population'] = df['Population'].apply(clean_currency).astype('float')
#df['Population']
df.dtypes
# Out:
# City                                    category
# Population                               float64
# Violent crime                           category
# Murder and nonnegligent manslaughter       Int64
# Rape (revised definition)               category
# Rape (legacy definition)                category
# Robbery                                 category
# Aggravated assault                      category
# Property crime                          category
# Burglary                                category
# Larceny-theft                           category
# Motor vehicle theft                     category
# Arson                                   category
# dtype: object

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# Ответ - количественные поля: population, arson, violent crime и т.д.
# Категориальные: City

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#колонка 1
df[df['Murder and nonnegligent manslaughter'] >= 66]
# Out:
#             City Population Violent crime  \
# 233  Los Angeles  3,962,726        25,156
# 281      Oakland    419,481         6,051
#
#      Murder and nonnegligent manslaughter Rape (revised definition)  \
# 233                                   282                     2,209
# 281                                    85                       285
#
#     Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 233                      NaN   8,952             13,713         93,503
# 281                      NaN   3,290              2,391         24,568
#
#     Burglary Larceny-theft Motor vehicle theft  Arson
# 233   16,160        61,191              16,152  1,131
# 281    3,333        14,846               6,389    179

# %%
#колонка 2
df[df['Population'] > 1234567]
# Out:
#             City  Population Violent crime  \
# 233  Los Angeles   3962726.0        25,156
# 351    San Diego   1400467.0         5,582
#
#      Murder and nonnegligent manslaughter Rape (revised definition)  \
# 233                                   282                     2,209
# 351                                    37                       566
#
#     Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 233                      NaN   8,952             13,713         93,503
# 351                      NaN   1,378              3,601         29,158
#
#     Burglary Larceny-theft Motor vehicle theft  Arson
# 233   16,160        61,191              16,152  1,131
# 351    5,129        18,933               5,096    174

# %%
#колонка 3
df[(df['Murder and nonnegligent manslaughter'] < 2)  & (df['Population'] > 111111)]
# Out:
#                  City  Population Violent crime  \
# 36           Berkeley    120387.0           530
# 61           Carlsbad    113972.0           172
# 93        Costa Mesa3    113477.0           386
# 123         Elk Grove    166183.0           586
# 149        Fullerton3    140771.0           389
# 180  Huntington Beach    203233.0           420
# 343         Roseville    131039.0           239
# 370       Santa Clara    123562.0           156
# 389      Simi Valley3    127472.0           174
# 405         Sunnyvale    152443.0           158
# 410          Temecula    111673.0           114
# 412     Thousand Oaks    129976.0           136
#
#      Murder and nonnegligent manslaughter Rape (revised definition)  \
# 36                                      1                        44
# 61                                      0                        33
# 93                                      1                        53
# 123                                     1                        33
# 149                                     0                        66
# 180                                     0                        52
# 343                                     0                        23
# 370                                     1                        20
# 389                                     1                        24
# 405                                     1                        29
# 410                                     1                         8
# 412                                     0                        26
#
#     Rape (legacy definition) Robbery Aggravated assault Property crime  \
# 36                       NaN     330                155          5,906
# 61                       NaN      38                101          2,134
# 93                       NaN     122                210          4,723
# 123                      NaN     105                447          3,120
# 149                      NaN     110                213          3,893
# 180                      NaN     117                251          4,942
# 343                      NaN      84                132          3,295
# 370                      NaN      71                 64          3,579
# 389                      NaN      45                104          1,513
# 405                      NaN      61                 67          2,355
# 410                      NaN      47                 58          2,917
# 412                      NaN      23                 87          1,577
#
#     Burglary Larceny-theft Motor vehicle theft Arson
# 36     1,090         4,099                 717    22
# 61       366         1,627                 141     8
# 93       698         3,558                 467    18
# 123      589         2,294                 237     4
# 149      468         2,958                 467    15
# 180      723         3,846                 373    23
# 343      521         2,469                 305    10
# 370      583         2,598                 398    10
# 389      255         1,146                 112     6
# 405      545         1,514                 296     9
# 410      459         2,116                 342     3
# 412      234         1,241                 102     9

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
#Группировка
df.groupby('Population').mean()
# Out:
# <ipython-input-165-94c5e9f5edf3>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Population').mean()
#             Murder and nonnegligent manslaughter
# Population
# 115.0                                        1.0
# 206.0                                        0.0
# 339.0                                        2.0
# 680.0                                        0.0
# 705.0                                        0.0
# ...                                          ...
# 520837.0                                    39.0
# 863782.0                                    53.0
# 1031458.0                                   30.0
# 1400467.0                                   37.0
# 3962726.0                                  282.0
#
# [460 rows x 1 columns]

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
